# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Delhi.csv")
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61392 entries, 0 to 61391
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   YEAR               61392 non-null  int64
#  1   MO                 61392 non-null  int64
#  2   DY                 61392 non-null  int64
#  3   HR                 61392 non-null  int64
#  4   ALLSKY_SFC_SW_DWN  61392 non-null  float64
#  5   T2M                61392 non-null  float64
#  6   RH2M               61392 non-null  float64
#  7   PS                 61392 non-null  float64
#  8   WS10M              61392 non-null  float64
#  9   ALLSKY_KT          61392 non-null  float64
#  10  PRECTOTCORR        61392 non-null  float64
#  11  SZA                61392 non-null  float64
# dtypes: float64(8), int64(4)
# memory usage: 5.6 MB

# %%
# df.isnull().sum()
(df == -999).sum()
# Out:
# YEAR                     0
# MO                       0
# DY                       0
# HR                       0
# ALLSKY_SFC_SW_DWN        0
# T2M                      0
# RH2M                     0
# PS                       0
# WS10M                    0
# ALLSKY_KT            29679
# PRECTOTCORR              0
# SZA                      0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['YEAR', 'MO', 'DY', 'HR', 'ALLSKY_SFC_SW_DWN', 'T2M', 'RH2M', 'PS',
#        'WS10M', 'ALLSKY_KT', 'PRECTOTCORR', 'SZA'],
#       dtype='str')

# %%
df["datetime"] = pd.to_datetime(
    df[["YEAR", "MO", "DY", "HR"]].rename(columns={
        "YEAR":"year",
        "MO":"month",
        "DY":"day",
        "HR":"hour"
    })
)
df = df.sort_values("datetime")

# %%
df.replace(-999, np.nan, inplace=True)
df.dropna(inplace=True)
(df == -999).sum()
# Out:
# YEAR                 0
# MO                   0
# DY                   0
# HR                   0
# ALLSKY_SFC_SW_DWN    0
# T2M                  0
# RH2M                 0
# PS                   0
# WS10M                0
# ALLSKY_KT            0
# PRECTOTCORR          0
# SZA                  0
# datetime             0
# dtype: int64

# %%
df["hour"] = df["datetime"].dt.hour
df["month"] = df["datetime"].dt.month
df["dayofyear"] = df["datetime"].dt.dayofyear

# %%
y = df["ALLSKY_SFC_SW_DWN"]
X = df[
    ["ALLSKY_KT",
    "T2M",
    "RH2M",
    "PS",
    "WS10M",
    "PRECTOTCORR",
    "hour",
    "month",
    "dayofyear"]
]

# %%
split = int(len(df)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimator = 200,
    learning_rate = 0.05,
    max_depth = 6,
    random_state = 42
)

xgb.fit(X_train, y_train)
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [16:09:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimator=200,
#              n_estimators=None, n_jobs=None, ...)

# %%
xgb_pred = xgb.predict(X_test)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

mae = mean_absolute_error(y_test,xgb_pred)

rmse = np.sqrt(mean_squared_error(y_test,xgb_pred))

r2 = r2_score(y_test,xgb_pred)

print("MAE : ",mae)
print("RMSE : " ,rmse)
print("R2_Score : ", r2)
# Out:
# MAE :  13.72168442172976
# RMSE :  19.05690078461285
# R2_Score :  0.9944135500026614

# %%
print(X.columns)
print("ALLSKY_SFC_SW_DWN" in X.columns)

print(X.columns.tolist())
# Out:
# Index(['ALLSKY_KT', 'T2M', 'RH2M', 'PS', 'WS10M', 'PRECTOTCORR', 'hour',
#        'month', 'dayofyear'],
#       dtype='str')
# False
# ['ALLSKY_KT', 'T2M', 'RH2M', 'PS', 'WS10M', 'PRECTOTCORR', 'hour', 'month', 'dayofyear']

# %%
import matplotlib.pyplot as plt

importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": xgb.feature_importances_
})

importance = importance.sort_values(
    "Importance",
    ascending=False
)

print(importance)

plt.figure(figsize=(8,5))
plt.barh(
    importance["Feature"],
    importance["Importance"]
)
plt.show()
# Out:
#        Feature  Importance
# 0    ALLSKY_KT    0.795337
# 5  PRECTOTCORR    0.078681
# 1          T2M    0.060627
# 6         hour    0.044534
# 8    dayofyear    0.007729
# 7        month    0.005964
# 3           PS    0.004714
# 4        WS10M    0.001370
# 2         RH2M    0.001044

# %%
corr = df.corr(numeric_only=True)

target_corr = (
    corr["ALLSKY_SFC_SW_DWN"].sort_values(ascending=False)
)
print(target_corr)
# Out:
# ALLSKY_SFC_SW_DWN    1.000000
# ALLSKY_KT            0.875902
# T2M                  0.483178
# WS10M                0.250024
# DY                  -0.001588
# hour                -0.006359
# HR                  -0.006359
# YEAR                -0.010225
# PS                  -0.040354
# PRECTOTCORR         -0.082252
# month               -0.098016
# MO                  -0.098016
# dayofyear           -0.098704
# RH2M                -0.478501
# SZA                 -0.875566
# Name: ALLSKY_SFC_SW_DWN, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(
    corr, 
    cmap="coolwarm"
)

plt.title("Correlation Matrix")
plt.show()

# %%
df["target_1h"] = df["ALLSKY_SFC_SW_DWN"].shift(-1)
df["target_6h"] = df["ALLSKY_SFC_SW_DWN"].shift(-6)
df["target_12h"] = df["ALLSKY_SFC_SW_DWN"].shift(-12)
df["target_24h"] = df["ALLSKY_SFC_SW_DWN"].shift(-24)

df.dropna(inplace=True)

# %%
y = df["target_1h"]
X = df[
    ["ALLSKY_KT",
    "T2M",
    "RH2M",
    "PS",
    "WS10M",
    "PRECTOTCORR",
    "hour",
    "month",
    "dayofyear"]
]

# %%
split = int(len(df)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimator = 200,
    learning_rate = 0.05,
    max_depth = 6,
    random_state = 42
)

xgb.fit(X_train, y_train)
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [16:09:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimator=200,
#              n_estimators=None, n_jobs=None, ...)

# %%
pred = xgb.predict(X_test)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

mae = mean_absolute_error(y_test,pred)

rmse = np.sqrt(
    mean_squared_error(y_test,pred)
)

r2 = r2_score(y_test,pred)

print("MAE :",mae)
print("RMSE :",rmse)
print("R2 :",r2)
# Out:
# MAE : 23.109149379536117
# RMSE : 36.52485949513493
# R2 : 0.9794804998240632

# %%
y = df["target_6h"]
X = df[
    ["ALLSKY_KT",
    "T2M",
    "RH2M",
    "PS",
    "WS10M",
    "PRECTOTCORR",
    "hour",
    "month",
    "dayofyear"]
]

# %%
split = int(len(df)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimator = 200,
    learning_rate = 0.05,
    max_depth = 6,
    random_state = 42
)

xgb.fit(X_train, y_train)
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [16:09:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimator=200,
#              n_estimators=None, n_jobs=None, ...)

# %%
pred = xgb.predict(X_test)
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

mae = mean_absolute_error(y_test,pred)

rmse = np.sqrt(
    mean_squared_error(y_test,pred)
)

r2 = r2_score(y_test,pred)

print("MAE :",mae)
print("RMSE :",rmse)
print("R2 :",r2)
# Out:
# MAE : 57.44403648655059
# RMSE : 84.99245822941548
# R2 : 0.8889202695065032

# %%
y = df["target_6h"]
X = df[
    ["ALLSKY_KT",
    "T2M",
    "RH2M",
    "PS",
    "WS10M",
    "PRECTOTCORR",
    "hour",
    "month",
    "dayofyear"]
]

split = int(len(df)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimator = 200,
    learning_rate = 0.05,
    max_depth = 6,
    random_state = 42
)

xgb.fit(X_train, y_train)

pred = xgb.predict(X_test)
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

mae = mean_absolute_error(y_test,pred)

rmse = np.sqrt(
    mean_squared_error(y_test,pred)
)

r2 = r2_score(y_test,pred)

print("MAE :",mae)
print("RMSE :",rmse)
print("R2 :",r2)
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [16:09:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# MAE : 57.44403648655059
# RMSE : 84.99245822941548
# R2 : 0.8889202695065032

# %%
y = df["target_12h"]
X = df[
    ["ALLSKY_KT",
    "T2M",
    "RH2M",
    "PS",
    "WS10M",
    "PRECTOTCORR",
    "hour",
    "month",
    "dayofyear"]
]

split = int(len(df)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimator = 200,
    learning_rate = 0.05,
    max_depth = 6,
    random_state = 42
)

xgb.fit(X_train, y_train)

pred = xgb.predict(X_test)
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

mae = mean_absolute_error(y_test,pred)

rmse = np.sqrt(
    mean_squared_error(y_test,pred)
)

r2 = r2_score(y_test,pred)

print("MAE :",mae)
print("RMSE :",rmse)
print("R2 :",r2)
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [16:09:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# MAE : 65.15595007098185
# RMSE : 97.12434673978508
# R2 : 0.8548526381211851

# %%
y = df["target_24h"]
X = df[
    ["ALLSKY_KT",
    "T2M",
    "RH2M",
    "PS",
    "WS10M",
    "PRECTOTCORR",
    "hour",
    "month",
    "dayofyear"]
]

split = int(len(df)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimator = 200,
    learning_rate = 0.05,
    max_depth = 6,
    random_state = 42
)

xgb.fit(X_train, y_train)

pred = xgb.predict(X_test)
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

mae = mean_absolute_error(y_test,pred)

rmse = np.sqrt(
    mean_squared_error(y_test,pred)
)

r2 = r2_score(y_test,pred)

print("MAE :",mae)
print("RMSE :",rmse)
print("R2 :",r2)
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [16:09:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# MAE : 79.46366759061286
# RMSE : 110.86564488331067
# R2 : 0.8109028699489197

# %%
results = pd.DataFrame({
    "Horizon":["1h", "6h", "12h", "24h"],
    "MAE":[23.109149379536117,57.44403648655059,65.15595007098185,79.46366759061286],
    "RMSE":[36.52485949513493,84.99245822941548,97.12434673978508,110.86564488331067],
    "R2":[0.9794804998240632,0.8889202695065032,0.8548526381211851, 0.8109028699489197]
})

print(results)
# Out:
#   Horizon        MAE        RMSE        R2
# 0      1h  23.109149   36.524859  0.979480
# 1      6h  57.444036   84.992458  0.888920
# 2     12h  65.155950   97.124347  0.854853
# 3     24h  79.463668  110.865645  0.810903

# %%
xgb.fit(X_train,y_train)

xgb_train_pred = xgb.predict(X_train)
xgb_test_pred = xgb.predict(X_test)
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/xgboost/training.py:200: UserWarning: [16:09:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
train_residuals = y_train.values - xgb_train_pred
test_residuals = y_test.values - xgb_test_pred

print(train_residuals[:10])
# Out:
# [ 83.8407959   25.36900757  43.92626343  33.67961304  32.75445068
#   16.96287384 -11.48213074  41.96827698  46.55651245  11.71908081]

# %%
from sklearn.preprocessing import MinMaxScaler

res_scaler = MinMaxScaler()

train_residuals_scaled = res_scaler.fit_transform(
    train_residuals.reshape(-1,1)
)

test_residuals_scaled = res_scaler.transform(
    test_residuals.reshape(-1,1)
)

# %%
lookback = 24

import numpy as np

def create_sequences(data, lookback):

    X = []
    y = []

    for i in range(len(data)-lookback):

        X.append(data[i:i+lookback])

        y.append(data[i+lookback])

    return np.array(X), np.array(y)

X_res_train, y_res_train = create_sequences(
    train_residuals_scaled,
    lookback
)

X_res_test, y_res_test = create_sequences(
    test_residuals_scaled,
    lookback
)

# %%
print(X_res_train.shape)
print(y_res_train.shape)
# Out:
# (25327, 24, 1)
# (25327, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(
    LSTM(
        64,
        input_shape=(lookback,1)
    )
)

model.add(Dense(1))

model.compile(
    optimizer="adam",
    loss="mse"
)

model.summary()
# Out:
# /Users/ak/Desktop/projects/DL_wind_solar_forecast/tf_env/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_res_train,
    y_res_train,
    epochs=20,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0068 - val_loss: 0.0036
# Epoch 2/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 3/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 4/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 5/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 6/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 7/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 8/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 9/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 10/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 11/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 12/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 13/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 14/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 15/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 16/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 17/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 18/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 19/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 20/20
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0025 - val_loss: 0.0021

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','validation'])
plt.show()

# %%
residual_pred_scaled = model.predict(
    X_res_test
)
# Out:
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step

# %%
residual_pred = res_scaler.inverse_transform(
    residual_pred_scaled
)

# %%
lookback = 24
xgb_test_aligned = xgb_test_pred[lookback:]

y_test_aligned = y_test.values[lookback:]

hybrid_pred = (
    xgb_test_aligned
    +
    residual_pred.flatten()
)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

mae = mean_absolute_error(
    y_test_aligned,
    hybrid_pred
)

rmse = np.sqrt(
    mean_squared_error(
        y_test_aligned,
        hybrid_pred
    )
)

r2 = r2_score(
    y_test_aligned,
    hybrid_pred
)

print("Hybrid MAE :", mae)
print("Hybrid RMSE :", rmse)
print("Hybrid R2 :", r2)


plt.figure(figsize=(15,5))

plt.plot(
    df["datetime"][:1000],
    df["ALLSKY_SFC_SW_DWN"][:1000]
)

plt.title("Shimla Solar Irradiance")
plt.show()
# Out:
# Hybrid MAE : 44.521881069766984
# Hybrid RMSE : 59.65402837498734
# Hybrid R2 : 0.9453282139732095
